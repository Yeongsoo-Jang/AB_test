# %%
## 라이브러리 임포트
import requests
import pprint
import json
import pandas as pd
import os
from datetime import date, timedelta, datetime
from dotenv import load_dotenv
load_dotenv()
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %% [markdown]
# ### 자전거 대여 기록

# %%
class SeoulBikeAPI:
       
    def __init__(self, api_key=None):
        # API 키 설정 (환경 변수 또는 직접 입력)
        self.api_key = api_key or os.getenv('seoul_api_key')
        if not self.api_key:
            raise ValueError("API Key is required. Set it as an environment variable or pass it explicitly.")
    
    def generate_date_range(self, start, end):
        """날짜 범위를 생성하는 제너레이터"""
        current_date = start
        while current_date <= end:
            yield current_date
            current_date += timedelta(days=1)
    
    def fetch_data(self, start=date(2024, 6, 1), end=date(2024, 12, 31)):
        """지정된 날짜 범위에 대해 데이터를 가져옵니다."""
        if start > end:
            raise ValueError("Start date must be earlier than or equal to the end date.")
        
        all_data = []  # 모든 날짜의 데이터를 저장할 리스트
        
        for single_date in self.generate_date_range(start, end):
            formatted_date = single_date.strftime("%Y-%m-%d")
            
            for hour in range(0, 24):  # 시간별 데이터 호출
                for start_idx in range(1, 20001, 1000):  # 1~1000, 1001~2000 ... 호출
                    end_idx = start_idx + 999
                    
                    url = f'http://openapi.seoul.go.kr:8088/{self.api_key}/json/tbCycleRentData/{start_idx}/{end_idx}/{formatted_date}/{hour}'
                    
                    try:
                        response = requests.get(url)
                        response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
                        data = response.json()
                        
                        # JSON 데이터에서 'rentData' -> 'row' 항목 추출
                        if 'rentData' in data and 'row' in data['rentData']:
                            all_data.extend(data['rentData']['row'])  # 리스트에 추가
                        else:
                            print(f"No data found for {formatted_date} hour {hour}, range {start_idx}-{end_idx}")
                            break  # 데이터가 없으면 해당 시간대 종료
                    
                    except requests.exceptions.RequestException as e:
                        print(f"Error fetching data for {formatted_date} hour {hour}, range {start_idx}-{end_idx}: {e}")
                        break  # 오류 발생 시 다음 시간대로 넘어감
        
        return all_data
    
    def fetch_data_as_dataframe(self, start=date(2024, 6, 1), end=date(2024, 12, 31)):
        """지정된 날짜 범위에 대해 데이터를 DataFrame 형식으로 반환합니다."""
        all_data = self.fetch_data(start=start, end=end)
        print("모든 데이터 호출 완료!")
        print("데이터 프레임 변환 시작!")
        # 리스트를 DataFrame으로 변환
        if all_data:
            df = pd.DataFrame(all_data)
            print("데이터 프레임 변환 끝!")
            return df
        else:
            print("No data available to create a DataFrame.")
            return pd.DataFrame()  # 빈 DataFrame 반환

# %%
# 데이터프레임 생성

api_key = os.getenv('seoul_api_key')

# 객체 생성
bike_api = SeoulBikeAPI(api_key)

for month in range(7, 13):
    # 원하는 날짜 범위를 설정
    start_date = date(2024, month, 1)
    end_date = (start_date.replace(day=28) + timedelta(days=4)).replace(day=1) - timedelta(days=1)  # 해당 월의 마지막 날 계산

    # 데이터를 DataFrame으로 가져오기
    df = bike_api.fetch_data_as_dataframe(start=start_date, end=end_date)

    # CSV 파일로 저장
    df.to_csv(f'./raw_data/rental_history_raw_{start_date}-{end_date}.csv', sep=',', encoding='utf-8', index=False)
class SeoulBikeInfo:
    def __init__(self, api_key=None):
        """
        API 키를 초기화합니다.
        :param api_key: 서울시 공공데이터 API 키 (환경 변수 또는 직접 입력)
        """
        self.api_key = api_key or os.getenv('seoul_api_key')
        if not self.api_key:
            raise ValueError("API Key가 필요합니다. 환경 변수로 설정하거나 직접 전달하세요.")
    
    def fetch_bike_list(self, start=1, end=1000):
        """
        서울시 공공자전거 대여소 정보를 가져옵니다.
        :param start: 데이터 시작 위치 (기본값: 1)
        :param end: 데이터 종료 위치 (기본값: 1000)
        :return: JSON 데이터
        """
        url = f'http://openapi.seoul.go.kr:8088/{self.api_key}/json/bikeList/{start}/{end}/'
        
        try:
            response = requests.get(url)
            response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
            data = response.json()
            
            # rentBikeStatus -> row 데이터 반환
            if 'rentBikeStatus' in data and 'row' in data['rentBikeStatus']:
                return data['rentBikeStatus']['row']
            else:
                raise ValueError("API 응답에 'rentBikeStatus' 또는 'row' 데이터가 없습니다.")
        
        except requests.exceptions.RequestException as e:
            print(f"데이터를 가져오는 중 오류가 발생했습니다: {e}")
            return []
    
    def get_bike_data_as_dataframe(self, start=1, end=1000):
        """
        대여소 데이터를 DataFrame 형식으로 반환합니다.
        :param start: 데이터 시작 위치 (기본값: 1)
        :param end: 데이터 종료 위치 (기본값: 1000)
        :return: pandas DataFrame
        """
        bike_data = self.fetch_bike_list(start=start, end=end)
        
        if bike_data:
            # JSON 데이터를 DataFrame으로 변환
            df = pd.DataFrame(bike_data)
            return df
        else:
            print("가져온 데이터가 없습니다.")
            return pd.DataFrame()  # 빈 DataFrame 반환

# %%
# # API 키 설정 (환경 변수 또는 직접 입력)
# api_key = os.getenv('seoul_api_key')

# # 객체 생성
# bike_api = SeoulBikeInfo(api_key)

# # 대여소 정보를 DataFrame으로 변환
# bike_df = bike_api.get_bike_data_as_dataframe(start=1, end=1000)
# bike_df2 = bike_api.get_bike_data_as_dataframe(start=1001, end=2000)
# bike_df3 = bike_api.get_bike_data_as_dataframe(start=2001, end=3000)

# bike_info = pd.concat([bike_df, bike_df2, bike_df3], ignore_index=True)

# # CSV 파일로 저장
# bike_info.to_csv("seoul_bike_info.csv", sep = ',', encoding='utf-8', index=False)

# %% [markdown]
# ### 자전거 대여소별 대여 건수 데이터

# %%
# 자전거 대여 건수 데이터 호출
class SeoulBikeUsage:
    def __init__(self, api_key=None):
        """
        API 키를 초기화합니다.
        :param api_key: 서울시 공공데이터 API 키 (환경 변수 또는 직접 입력)
        """
        self.api_key = api_key or os.getenv('seoul_api_key')
        if not self.api_key:
            raise ValueError("API Key가 필요합니다. 환경 변수로 설정하거나 직접 전달하세요.")
    
    def generate_date_range(self, start_date, end_date):
        """
        시작 날짜와 종료 날짜 사이의 날짜 범위를 생성합니다.
        :param start_date: 시작 날짜 (문자열 형식: 'YYYY-MM-DD')
        :param end_date: 종료 날짜 (문자열 형식: 'YYYY-MM-DD')
        :return: 날짜 문자열의 제너레이터
        """
        current_date = datetime.strptime(start_date, "%Y-%m-%d")
        end_date = datetime.strptime(end_date, "%Y-%m-%d")
        
        while current_date <= end_date:
            yield current_date.strftime("%Y-%m-%d")
            current_date += timedelta(days=1)
    
    def fetch_data(self, start_date="2024-01-01", end_date="2024-12-31", row_start=1, row_end=1000):
        """
        지정된 날짜 범위의 데이터를 API로 호출하여 수집합니다.
        :param start_date: 데이터 수집 시작 날짜 (기본값: '2024-01-01')
        :param end_date: 데이터 수집 종료 날짜 (기본값: '2024-12-31')
        :param row_start: 데이터 시작 위치 (기본값: 1)
        :param row_end: 데이터 종료 위치 (기본값: 1000)
        :return: JSON 데이터 리스트
        """
        all_data = []  # 모든 데이터를 저장할 리스트
        
        for single_date in self.generate_date_range(start_date, end_date):
            url = f'http://openapi.seoul.go.kr:8088/{self.api_key}/json/tbCycleUseStatus/{row_start}/{row_end}/{single_date}'
            
            try:
                response = requests.get(url)
                response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
                data = response.json()
                
                # useStatus -> row 데이터 추가
                if 'useStatus' in data and 'row' in data['useStatus']:
                    all_data.extend(data['useStatus']['row'])
                else:
                    print(f"{single_date}에 데이터가 없습니다.")
            
            except requests.exceptions.RequestException as e:
                print(f"{single_date} 데이터를 가져오는 중 오류가 발생했습니다: {e}")
        
        return all_data
    
    def fetch_data_as_dataframe(self, start_date="2024-01-01", end_date="2024-12-31", row_start=1, row_end=1000):
        """
        지정된 날짜 범위의 데이터를 DataFrame 형식으로 반환합니다.
        :param start_date: 데이터 수집 시작 날짜 (기본값: '2024-01-01')
        :param end_date: 데이터 수집 종료 날짜 (기본값: '2024-12-31')
        :param row_start: 데이터 시작 위치 (기본값: 1)
        :param row_end: 데이터 종료 위치 (기본값: 1000)
        :return: pandas DataFrame
        """
        all_data = self.fetch_data(start_date=start_date, end_date=end_date, row_start=row_start, row_end=row_end)
        
        if all_data:
            # JSON 데이터를 DataFrame으로 변환
            df = pd.DataFrame(all_data)
            return df
        else:
            print("가져온 데이터가 없습니다.")
            return pd.DataFrame()  # 빈 DataFrame 반환

# %%
# # API 키 설정 (환경 변수 또는 직접 입력)
# api_key = os.getenv('seoul_api_key')

# # 객체 생성
# bike_usage_api = SeoulBikeUsage(api_key)

# # 2024년 1월 1일부터 2024년 12월 31일까지 데이터를 DataFrame으로 가져오기
# bike_usage_df = bike_usage_api.fetch_data_as_dataframe(start_date="2024-01-01", end_date="2024-12-31")
# bike_usage_df2 = bike_usage_api.fetch_data_as_dataframe(start_date="2024-01-01", end_date="2024-12-31", row_start=1001, row_end=2000)
# bike_usage_df3 = bike_usage_api.fetch_data_as_dataframe(start_date="2024-01-01", end_date="2024-12-31", row_start=2001, row_end=3000)

# bike_usage_df = pd.concat([bike_usage_df, bike_usage_df2, bike_usage_df3], ignore_index=True)

# # CSV 파일로 저장
# bike_usage_df.to_csv("seoul_bike_usage.csv", index=False)

# %% [markdown]
# ### 대여소 주변 핫플레이스 정보

# %%
# 대여소 주변 관광지 정보

class SeoulBikeHotPlaces:
    def __init__(self, api_key=None):
        """
        Google Places API 키를 초기화합니다.
        :param api_key: Google Places API 키 (환경 변수 또는 직접 입력)
        """
        self.api_key = api_key or os.getenv('gmaps_api_key')
        if not self.api_key:
            raise ValueError("Google Places API Key가 필요합니다. 환경 변수로 설정하거나 직접 전달하세요.")
    
    def get_hot_places(self, latitude, longitude, radius=500, place_type="tourist_attraction", max_results=10):
        """
        특정 위치 주변의 핫플레이스를 검색합니다.
        :param latitude: 검색 중심점의 위도
        :param longitude: 검색 중심점의 경도
        :param radius: 검색 반경 (미터 단위, 기본값: 500m)
        :param place_type: 검색할 장소 유형 (예: restaurant, cafe, park 등)
        :param max_results: 반환할 최대 결과 수 (기본값: 10)
        :return: 핫플레이스 정보 리스트
        """
        base_url = "https://places.googleapis.com/v1/places:searchNearby"
        
        # 요청 본문 (JSON 형식)
        request_body = {
            "includedTypes": [place_type],
            "maxResultCount": max_results,
            "locationRestriction": {
                "circle": {
                    "center": {
                        "latitude": latitude,
                        "longitude": longitude
                    },
                    "radius": radius
                }
            }
        }
        
        # 요청 헤더
        headers = {
            "Content-Type": "application/json",
            "X-Goog-Api-Key": self.api_key,
            "X-Goog-FieldMask": "places.displayName,places.location,places.rating,places.userRatingCount"
        }
        
        try:
            # POST 요청 전송
            response = requests.post(base_url, json=request_body, headers=headers)
            response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
            
            # 응답 데이터 파싱
            data = response.json()
            
            # 결과에서 필요한 정보 추출
            places = []
            for place in data.get("places", []):
                places.append({
                    "name": place.get("displayName", {}).get("text", "Unknown"),
                    "latitude": place["location"]["latitude"],
                    "longitude": place["location"]["longitude"],
                    "rating": place.get("rating"),
                    "user_ratings_total": place.get("userRatingCount")
                })
            
            return places
        
        except requests.exceptions.RequestException as e:
            print(f"데이터를 가져오는 중 오류가 발생했습니다: {e}")
            return []
    
    def get_places_for_stations(self, bike_stations_df, radius=500, place_type="tourist_attraction", max_results=10):
        """
        자전거 대여소 데이터프레임을 기반으로 각 대여소 주변 핫플레이스를 검색합니다.
        :param bike_stations_df: 자전거 대여소 정보가 포함된 DataFrame (latitude와 longitude 열 포함)
        :param radius: 검색 반경 (미터 단위, 기본값: 500m)
        :param place_type: 검색할 장소 유형 (예: restaurant, cafe, park 등)
        :param max_results: 반환할 최대 결과 수 (기본값: 10)
        :return: 대여소별 핫플레이스 정보를 포함한 DataFrame
        """
        all_places = []
        
        for _, row in bike_stations_df.iterrows():
            station_id = row["stationId"]
            station_name = row["stationName"]
            latitude = row["stationLatitude"]
            longitude = row["stationLongitude"]
            
            print(f"대여소 '{station_name}' 주변 핫플레이스 검색 중...")
            
            # 특정 대여소 주변 핫플레이스 검색
            places = self.get_hot_places(latitude, longitude, radius=radius, place_type=place_type, max_results=max_results)
            
            # 각 장소에 대여소 ID와 이름 추가
            for place in places:
                place["stationId"] = station_id
                place["stationName"] = station_name
            
            all_places.extend(places)
        
        # 결과를 DataFrame으로 변환
        return pd.DataFrame(all_places)

# %%
# # Google Places API 키 설정 (환경 변수 또는 직접 입력)
# api_key = os.getenv('gmaps_api_key')

# # 객체 생성
# hot_places_api = SeoulBikeHotPlaces(api_key)

# # 자전거 대여소 데이터
# bike_stations_df = bike_info[['stationName', 'stationLatitude', 'stationLongitude', 'stationId']]
# bike_stations_df.drop_duplicates(inplace=True)

# # 각 대여소 주변 500m 반경의 관광지(Tourist Attraction) 정보 가져오기
# hot_places_df = hot_places_api.get_places_for_stations(bike_stations_df, radius=500, place_type="cafe")

# # CSV 파일로 저장
# hot_places_df.to_csv("bike_station_hot_places.csv", index=False, sep=',', encoding='utf-8')

# %% [markdown]
# ### 날씨 데이터 API 호출

# %%
# 기상청 API 허브 데이터 호출
class KMADataAPI:
    def __init__(self, api_key):
        """
        기상청 API 클래스 초기화
        :param api_key: 기상청 API 인증키
        """
        self.api_key = api_key
        self.base_url = "https://apihub.kma.go.kr/api/typ01/url/kma_sfctm2.php"
        self.raw_data = None
        self.columns = ["TM", "STN", "TA", "HM", "RN", "WS", "SD_TOT", "RN_JUN"]
        self.data = []

    def fetch_data(self, tm, stn):
        """
        기상청 API에서 데이터를 가져옵니다.
        :param tm: 관측 시각 (예: '202401010000')
        :param stn: 관측소 번호 (예: '108'은 서울)
        """
        params = {
            "tm": tm,
            "stn": stn,
            "help": 0,  # 도움말 제거
            "authKey": self.api_key,
        }
        
        # API 호출
        response = requests.get(self.base_url, params=params)
        
        if response.status_code == 200:
            self.raw_data = response.text
            print(f"API 호출 성공! 시각: {tm}")
        else:
            raise Exception(f"API 호출 실패! 상태 코드: {response.status_code}, 시각: {tm}")

    def parse_data(self):
        """
        텍스트 데이터에서 실제 관측 데이터를 추출합니다.
        """
        if not self.raw_data:
            raise ValueError("데이터가 없습니다. 먼저 fetch_data를 호출하세요.")
        
        lines = self.raw_data.split("\n")
        
        # 데이터 행 추출 (숫자로 시작하는 행)
        data_lines = [line for line in lines if re.match(r"^\d", line)]
        
        for line in data_lines:
            # 필요한 열만 고정된 폭으로 분리
            row = [
                line[0:10].strip(),  # TM (관측 시각)
                line[12:16].strip(), # STN (관측소 ID)
                line[63:68].strip(), # TA (기온)
                line[75:80].strip(), # HM (습도)
                line[87:93].strip(), # RN (강수량)
                line[21:25].strip(), # WS (풍속)
                line[131:136].strip(), # SD_TOT (적설량)
                line[104:109].strip()  # RN_JUN (일강수량)
            ]
            self.data.append(row)

    def to_dataframe(self):
        """
        파싱한 데이터를 판다스 데이터프레임으로 변환합니다.
        """
        if not self.data:
            raise ValueError("Data가 없습니다. parse_data를 먼저 실행하세요.")
        
        df = pd.DataFrame(self.data, columns=self.columns)
        return df

def fetch_all_data(api_key, start_time, end_time, stn):
    """
    주어진 시간 범위 내에서 데이터를 반복적으로 호출하여 병합합니다.
    :param api_key: 기상청 API 인증키
    :param start_time: 시작 시각 (datetime 객체)
    :param end_time: 종료 시각 (datetime 객체)
    :param stn: 관측소 번호
    :return: 병합된 데이터프레임
    """
    kma_api = KMADataAPI(api_key)
    current_time = start_time
    all_data = []

    while current_time <= end_time:
        tm_str = current_time.strftime("%Y%m%d%H%M")  # 'YYYYMMDDHHMM' 형식으로 변환
        
        try:
            kma_api.fetch_data(tm=tm_str, stn=stn)  # API 호출
            kma_api.parse_data()                   # 데이터 파싱
            
            # 파싱된 데이터를 저장하고 초기화
            all_data.extend(kma_api.data)
            kma_api.data = []  # 다음 호출을 위해 초기화
            
        except Exception as e:
            print(f"오류 발생: {e}")
        
        # 다음 시간으로 이동 (1시간 단위 증가)
        current_time += timedelta(hours=1)

    # 모든 데이터를 하나의 데이터프레임으로 병합
    df = pd.DataFrame(all_data, columns=kma_api.columns)
    return df

# %%
# api_key = os.getenv('weather_api_key')  # 환경 변수에서 가져오기

# # 시작 및 종료 시간 설정
# start_time = datetime(2024, 1, 1, 0, 0)   # 2024년 1월 1일 00시
# end_time = datetime(2024, 12, 31, 23, 0) # 2024년 12월 31일 23시

# # 전체 데이터 호출 및 병합
# df_all = fetch_all_data(api_key=api_key, start_time=start_time, end_time=end_time, stn="108")

# # 결과 출력
# print(df_all.head())

# # CSV 파일로 저장하기 (선택 사항)
# df_all.to_csv("kma_weather_2024.csv", index=False, sep = ',', encoding = 'utf-8')

# %%
# json file 의 key 값 확인 (각 딕셔너리 값으로 이뤄져있음)
# response['rentData'].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
# json 파일의 row 데이터 로드 
# response['rentData']['row']
# Out:
# [{'BIKE_ID': 'SPB-82123',
#   'RENT_DT': '2024-12-01 01:01:12',
#   'RENT_ID': '04340',
#   'RENT_NM': '방배래미안아트힐아파트 앞',
#   'RENT_HOLD': '99',
#   'RTN_DT': '2024-12-01 01:01:15',
#   'RTN_ID': '04340',
#   'RTN_NM': '방배래미안아트힐아파트 앞',
#   'RTN_HOLD': '99',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1967',
#   'RENT_STATION_ID': 'ST-3220',
#   'RETURN_STATION_ID': 'ST-3220',
#   'BIKE_SE_CD': '새싹자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1'},
#  {'BIKE_ID': 'SPB-48788',
#   'RENT_DT': '2024-12-01 01:01:11',
#   'RENT_ID': '02531',
#   'RENT_NM': '멤피스아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:01:16',
#   'RTN_ID': '02531',
#   'RTN_NM': '멤피스아파트 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1968',
#   'RENT_STATION_ID': 'ST-1916',
#   'RETURN_STATION_ID': 'ST-1916',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '2'},
#  {'BIKE_ID': 'SPB-38818',
#   'RENT_DT': '2024-12-01 01:01:33',
#   'RENT_ID': '00383',
#   'RENT_NM': '신당역 12번 출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:01:35',
#   'RTN_ID': '00383',
#   'RTN_NM': '신당역 12번 출구 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1979',
#   'RENT_STATION_ID': 'ST-198',
#   'RETURN_STATION_ID': 'ST-198',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '3'},
#  {'BIKE_ID': 'SPB-63150',
#   'RENT_DT': '2024-12-01 01:01:22',
#   'RENT_ID': '00791',
#   'RENT_NM': '현대하이페리온',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:02:53',
#   'RTN_ID': '04514',
#   'RTN_NM': '목동성당 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1992',
#   'RENT_STATION_ID': 'ST-2016',
#   'RETURN_STATION_ID': 'ST-2764',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '4'},
#  {'BIKE_ID': 'SPB-53417',
#   'RENT_DT': '2024-12-01 01:01:14',
#   'RENT_ID': '00383',
#   'RENT_NM': '신당역 12번 출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:03:31',
#   'RTN_ID': '00383',
#   'RTN_NM': '신당역 12번 출구 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': '',
#   'BIRTH_YEAR': '1979',
#   'RENT_STATION_ID': 'ST-198',
#   'RETURN_STATION_ID': 'ST-198',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '5'},
#  {'BIKE_ID': 'SPB-38818',
#   'RENT_DT': '2024-12-01 01:02:39',
#   'RENT_ID': '00383',
#   'RENT_NM': '신당역 12번 출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:03:58',
#   'RTN_ID': '00383',
#   'RTN_NM': '신당역 12번 출구 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1979',
#   'RENT_STATION_ID': 'ST-198',
#   'RETURN_STATION_ID': 'ST-198',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '6'},
#  {'BIKE_ID': 'SPB-61221',
#   'RENT_DT': '2024-12-01 01:04:00',
#   'RENT_ID': '01911',
#   'RENT_NM': '구로디지털단지역 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:04:10',
#   'RTN_ID': '01911',
#   'RTN_NM': '구로디지털단지역 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-668',
#   'RETURN_STATION_ID': 'ST-668',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '7'},
#  {'BIKE_ID': 'SPB-38000',
#   'RENT_DT': '2024-12-01 01:01:39',
#   'RENT_ID': '00782',
#   'RENT_NM': '서남병원 후문',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:04:13',
#   'RTN_ID': '04538',
#   'RTN_NM': '양천공영차고지',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '603.68',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1970',
#   'RENT_STATION_ID': 'ST-2008',
#   'RETURN_STATION_ID': 'ST-3048',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '8'},
#  {'BIKE_ID': 'SPB-34663',
#   'RENT_DT': '2024-12-01 01:00:06',
#   'RENT_ID': '05061',
#   'RENT_NM': '우장산동 가곡어린이공원앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:05:07',
#   'RTN_ID': '02718',
#   'RTN_NM': '마곡수명산파크1단지',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '440.76',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1988',
#   'RENT_STATION_ID': 'ST-2888',
#   'RETURN_STATION_ID': 'ST-2034',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '9'},
#  {'BIKE_ID': 'SPB-31833',
#   'RENT_DT': '2024-12-01 01:00:20',
#   'RENT_ID': '02646',
#   'RENT_NM': '레이크펠리스101동앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:05:11',
#   'RTN_ID': '01269',
#   'RTN_NM': '리센츠아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '523.11',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2005',
#   'RENT_STATION_ID': 'ST-1867',
#   'RETURN_STATION_ID': 'ST-1088',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '10'},
#  {'BIKE_ID': 'SPB-69385',
#   'RENT_DT': '2024-12-01 01:00:34',
#   'RENT_ID': '00236',
#   'RENT_NM': '문래동자이아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:05:57',
#   'RTN_ID': '00284',
#   'RTN_NM': '센트럴 푸르지오 시티 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '820.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-285',
#   'RETURN_STATION_ID': 'ST-1650',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '11'},
#  {'BIKE_ID': 'SPB-65121',
#   'RENT_DT': '2024-12-01 01:02:34',
#   'RENT_ID': '00806',
#   'RENT_NM': '전자랜드 본관 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:06:02',
#   'RTN_ID': '04604',
#   'RTN_NM': '원효로다목적체육관 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '425.88',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1971',
#   'RENT_STATION_ID': 'ST-327',
#   'RETURN_STATION_ID': 'ST-2437',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '12'},
#  {'BIKE_ID': 'SPB-46818',
#   'RENT_DT': '2024-12-01 01:02:37',
#   'RENT_ID': '01149',
#   'RENT_NM': '신방화역환승주차장',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:06:15',
#   'RTN_ID': '02702',
#   'RTN_NM': '마곡 엠밸리2단지',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '260.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2007',
#   'RENT_STATION_ID': 'ST-975',
#   'RETURN_STATION_ID': 'ST-1727',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '13'},
#  {'BIKE_ID': 'SPB-82155',
#   'RENT_DT': '2024-12-01 01:01:42',
#   'RENT_ID': '00505',
#   'RENT_NM': '자양사거리 광진아크로텔 앞',
#   'RENT_HOLD': '99',
#   'RTN_DT': '2024-12-01 01:06:25',
#   'RTN_ID': '03569',
#   'RTN_NM': '건대병원후문',
#   'RTN_HOLD': '99',
#   'USE_MIN': '4',
#   'USE_DST': '1070.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-102',
#   'RETURN_STATION_ID': 'ST-2308',
#   'BIKE_SE_CD': '새싹자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '14'},
#  {'BIKE_ID': 'SPB-43488',
#   'RENT_DT': '2024-12-01 01:02:07',
#   'RENT_ID': '00779',
#   'RENT_NM': '신정1동 주민센터 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:06:29',
#   'RTN_ID': '04515',
#   'RTN_NM': '동문굿모닝탑',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '874.22',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2008',
#   'RENT_STATION_ID': 'ST-2005',
#   'RETURN_STATION_ID': 'ST-2765',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '15'},
#  {'BIKE_ID': 'SPB-35348',
#   'RENT_DT': '2024-12-01 01:04:05',
#   'RENT_ID': '01001',
#   'RENT_NM': '광진교 남단 사거리(천호공원 방면)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:06:38',
#   'RTN_ID': '01009',
#   'RTN_NM': '천호역4번출구(현대백화점)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '333.59',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-485',
#   'RETURN_STATION_ID': 'ST-493',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '16'},
#  {'BIKE_ID': 'SPB-45332',
#   'RENT_DT': '2024-12-01 01:06:40',
#   'RENT_ID': '00111',
#   'RENT_NM': '상수역 2번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:06:56',
#   'RTN_ID': '00111',
#   'RTN_NM': '상수역 2번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1990',
#   'RENT_STATION_ID': 'ST-15',
#   'RETURN_STATION_ID': 'ST-15',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '17'},
#  {'BIKE_ID': 'SPB-66455',
#   'RENT_DT': '2024-12-01 01:05:59',
#   'RENT_ID': '00270',
#   'RENT_NM': '증권거래소후문교차로',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:07:01',
#   'RTN_ID': '00270',
#   'RTN_NM': '증권거래소후문교차로',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1988',
#   'RENT_STATION_ID': 'ST-424',
#   'RETURN_STATION_ID': 'ST-424',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '18'},
#  {'BIKE_ID': 'SPB-67768',
#   'RENT_DT': '2024-12-01 01:06:50',
#   'RENT_ID': '01318',
#   'RENT_NM': '길음역 3번출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:07:28',
#   'RTN_ID': '01318',
#   'RTN_NM': '길음역 3번출구 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-563',
#   'RETURN_STATION_ID': 'ST-563',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '19'},
#  {'BIKE_ID': 'SPB-63959',
#   'RENT_DT': '2024-12-01 01:04:37',
#   'RENT_ID': '02102',
#   'RENT_NM': '봉림교 교통섬',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:07:51',
#   'RTN_ID': '03818',
#   'RTN_NM': '은천교회 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '701.46',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1996',
#   'RENT_STATION_ID': 'ST-702',
#   'RETURN_STATION_ID': 'ST-2996',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '20'},
#  {'BIKE_ID': 'SPB-67101',
#   'RENT_DT': '2024-12-01 01:00:14',
#   'RENT_ID': '00280',
#   'RENT_NM': '양평동6차현대아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:07:59',
#   'RTN_ID': '00236',
#   'RTN_NM': '문래동자이아파트 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1772.52',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2002',
#   'RENT_STATION_ID': 'ST-1539',
#   'RETURN_STATION_ID': 'ST-285',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '21'},
#  {'BIKE_ID': 'SPB-37734',
#   'RENT_DT': '2024-12-01 01:06:00',
#   'RENT_ID': '00228',
#   'RENT_NM': '선유도역 3번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:00',
#   'RTN_ID': '00229',
#   'RTN_NM': '양평1 보행육교 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '345.58',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1975',
#   'RENT_STATION_ID': 'ST-278',
#   'RETURN_STATION_ID': 'ST-279',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '22'},
#  {'BIKE_ID': 'SPB-32873',
#   'RENT_DT': '2024-12-01 01:07:57',
#   'RENT_ID': '01867',
#   'RENT_NM': '대륭포스트타워6차 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:06',
#   'RTN_ID': '01867',
#   'RTN_NM': '대륭포스트타워6차 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-1938',
#   'RETURN_STATION_ID': 'ST-1938',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '23'},
#  {'BIKE_ID': 'SPB-41493',
#   'RENT_DT': '2024-12-01 01:00:13',
#   'RENT_ID': '03504',
#   'RENT_NM': '원일교회',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:21',
#   'RTN_ID': '00555',
#   'RTN_NM': '구의3동주민센터',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1373.02',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2004',
#   'RENT_STATION_ID': 'ST-987',
#   'RETURN_STATION_ID': 'ST-381',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '24'},
#  {'BIKE_ID': 'SPB-55708',
#   'RENT_DT': '2024-12-01 01:01:05',
#   'RENT_ID': '02601',
#   'RENT_NM': '석촌호수 아뜰리에',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:23',
#   'RTN_ID': '01235',
#   'RTN_NM': '잠실트리지움310동 옆',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1145.83',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1992',
#   'RENT_STATION_ID': 'ST-1590',
#   'RETURN_STATION_ID': 'ST-553',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '25'},
#  {'BIKE_ID': 'SPB-35842',
#   'RENT_DT': '2024-12-01 01:03:31',
#   'RENT_ID': '01663',
#   'RENT_NM': '동해문화예술관앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:34',
#   'RTN_ID': '01601',
#   'RTN_NM': '석계역 문화광장 내 자전거 보관소',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '428.54',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-1280',
#   'RETURN_STATION_ID': 'ST-600',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '26'},
#  {'BIKE_ID': 'SPB-61473',
#   'RENT_DT': '2024-12-01 01:03:25',
#   'RENT_ID': '05306',
#   'RENT_NM': '동신아파트 후문 옆',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:35',
#   'RTN_ID': '02915',
#   'RTN_NM': '서울과학기술대학교(어학교육원)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '796.25',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2001',
#   'RENT_STATION_ID': 'ST-3060',
#   'RETURN_STATION_ID': 'ST-2081',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '27'},
#  {'BIKE_ID': 'SPB-72411',
#   'RENT_DT': '2024-12-01 01:08:31',
#   'RENT_ID': '02920',
#   'RENT_NM': '상계중학교(당현2교사거리)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:39',
#   'RTN_ID': '02920',
#   'RTN_NM': '상계중학교(당현2교사거리)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2007',
#   'RENT_STATION_ID': 'ST-2086',
#   'RETURN_STATION_ID': 'ST-2086',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '28'},
#  {'BIKE_ID': 'SPB-49394',
#   'RENT_DT': '2024-12-01 01:04:49',
#   'RENT_ID': '00747',
#   'RENT_NM': '목동3단지 상가',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:48',
#   'RTN_ID': '04526',
#   'RTN_NM': '목동아파트2단지 222동 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '622.87',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-1018',
#   'RETURN_STATION_ID': 'ST-2773',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '29'},
#  {'BIKE_ID': 'SPB-59312',
#   'RENT_DT': '2024-12-01 01:00:11',
#   'RENT_ID': '03570',
#   'RENT_NM': '구의역 리버비스타 오피스텔',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:56',
#   'RTN_ID': '00577',
#   'RTN_NM': '광진청소년수련관',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '3340.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2003',
#   'RENT_STATION_ID': 'ST-2309',
#   'RETURN_STATION_ID': 'ST-388',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '30'},
#  {'BIKE_ID': 'SPB-36139',
#   'RENT_DT': '2024-12-01 01:04:10',
#   'RENT_ID': '04543',
#   'RENT_NM': '오목교역 6번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:08:57',
#   'RTN_ID': '00781',
#   'RTN_NM': '신정보도육교 아래',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '680.61',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1961',
#   'RENT_STATION_ID': 'ST-3163',
#   'RETURN_STATION_ID': 'ST-2007',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '31'},
#  {'BIKE_ID': 'SPB-67872',
#   'RENT_DT': '2024-12-01 01:02:16',
#   'RENT_ID': '04508',
#   'RENT_NM': '유원목동아파트 103동 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:04',
#   'RTN_ID': '04535',
#   'RTN_NM': '목동12단지 아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1410.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2001',
#   'RENT_STATION_ID': 'ST-2760',
#   'RETURN_STATION_ID': 'ST-2960',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '32'},
#  {'BIKE_ID': 'SPB-67219',
#   'RENT_DT': '2024-12-01 01:01:29',
#   'RENT_ID': '02518',
#   'RENT_NM': '서초동 현대아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:08',
#   'RTN_ID': '02231',
#   'RTN_NM': '삼성타운(삼성생명) A동 맞은편',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1140.23',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1995',
#   'RENT_STATION_ID': 'ST-1903',
#   'RETURN_STATION_ID': 'ST-761',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '33'},
#  {'BIKE_ID': 'SPB-66076',
#   'RENT_DT': '2024-12-01 01:03:32',
#   'RENT_ID': '04514',
#   'RENT_NM': '목동성당 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:16',
#   'RTN_ID': '00794',
#   'RTN_NM': '양천문화회관',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '950.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1992',
#   'RENT_STATION_ID': 'ST-2764',
#   'RETURN_STATION_ID': 'ST-2395',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '34'},
#  {'BIKE_ID': 'SPB-49015',
#   'RENT_DT': '2024-12-01 01:03:10',
#   'RENT_ID': '05323',
#   'RENT_NM': '하계역 4번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:22',
#   'RTN_ID': '05317',
#   'RTN_NM': '공릉동 신도1차 아파트 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1020.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1996',
#   'RENT_STATION_ID': 'ST-3256',
#   'RETURN_STATION_ID': 'ST-3167',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '35'},
#  {'BIKE_ID': 'SPB-64048',
#   'RENT_DT': '2024-12-01 01:07:24',
#   'RENT_ID': '00114',
#   'RENT_NM': '홍대입구역 8번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:23',
#   'RTN_ID': '00114',
#   'RTN_NM': '홍대입구역 8번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2003',
#   'RENT_STATION_ID': 'ST-20',
#   'RETURN_STATION_ID': 'ST-20',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '36'},
#  {'BIKE_ID': 'SPB-39686',
#   'RENT_DT': '2024-12-01 01:01:56',
#   'RENT_ID': '04208',
#   'RENT_NM': '스타벅스(동교동) 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:31',
#   'RTN_ID': '00184',
#   'RTN_NM': '7번가피자 서교망원점',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1296.01',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1973',
#   'RENT_STATION_ID': 'ST-2532',
#   'RETURN_STATION_ID': 'ST-342',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '37'},
#  {'BIKE_ID': 'SPB-64413',
#   'RENT_DT': '2024-12-01 01:03:23',
#   'RENT_ID': '03432',
#   'RENT_NM': '종로2가 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:32',
#   'RTN_ID': '00336',
#   'RTN_NM': '충무로역 6번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1120.99',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1994',
#   'RENT_STATION_ID': 'ST-1829',
#   'RETURN_STATION_ID': 'ST-152',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '38'},
#  {'BIKE_ID': 'SPB-43013',
#   'RENT_DT': '2024-12-01 01:00:03',
#   'RENT_ID': '04491',
#   'RENT_NM': '장지역 1번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:33',
#   'RTN_ID': '04852',
#   'RTN_NM': '서울복합물류 게이트 1',
#   'RTN_HOLD': '0',
#   'USE_MIN': '9',
#   'USE_DST': '805.57',
#   'USR_CLS_CD': 'USR_003',
#   'RENT_STATION_ID': 'ST-2599',
#   'RETURN_STATION_ID': 'ST-2605',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '39'},
#  {'BIKE_ID': 'SPB-54297',
#   'RENT_DT': '2024-12-01 01:00:11',
#   'RENT_ID': '02614',
#   'RENT_NM': '가락고등학교 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:36',
#   'RTN_ID': '02632',
#   'RTN_NM': '석촌고분역 2번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '9',
#   'USE_DST': '2094.14',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2002',
#   'RENT_STATION_ID': 'ST-1706',
#   'RETURN_STATION_ID': 'ST-1859',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '40'},
#  {'BIKE_ID': 'SPB-40223',
#   'RENT_DT': '2024-12-01 01:01:51',
#   'RENT_ID': '02310',
#   'RENT_NM': '청담동 맥도날드 옆(위치)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:43',
#   'RTN_ID': '02313',
#   'RTN_NM': '금원빌딩 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1112.27',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1972',
#   'RENT_STATION_ID': 'ST-794',
#   'RETURN_STATION_ID': 'ST-796',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '41'},
#  {'BIKE_ID': 'SPB-54477',
#   'RENT_DT': '2024-12-01 01:09:08',
#   'RENT_ID': '02531',
#   'RENT_NM': '멤피스아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:44',
#   'RTN_ID': '02531',
#   'RTN_NM': '멤피스아파트 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1996',
#   'RENT_STATION_ID': 'ST-1916',
#   'RETURN_STATION_ID': 'ST-1916',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '42'},
#  {'BIKE_ID': 'SPB-48788',
#   'RENT_DT': '2024-12-01 01:01:58',
#   'RENT_ID': '02531',
#   'RENT_NM': '멤피스아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:45',
#   'RTN_ID': '02271',
#   'RTN_NM': '내방역 8번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '770.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1968',
#   'RENT_STATION_ID': 'ST-1916',
#   'RETURN_STATION_ID': 'ST-1163',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '43'},
#  {'BIKE_ID': 'SPB-45215',
#   'RENT_DT': '2024-12-01 01:07:23',
#   'RENT_ID': '01411',
#   'RENT_NM': '상봉시장앞 교차로 한성빌딩 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:51',
#   'RTN_ID': '01455',
#   'RTN_NM': '상봉역 2번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1998',
#   'RENT_STATION_ID': 'ST-912',
#   'RETURN_STATION_ID': 'ST-1375',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '44'},
#  {'BIKE_ID': 'SPB-61404',
#   'RENT_DT': '2024-12-01 01:07:01',
#   'RENT_ID': '04142',
#   'RENT_NM': '현대썬앤빌 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:52',
#   'RTN_ID': '00602',
#   'RTN_NM': '장안동 사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1963',
#   'RENT_STATION_ID': 'ST-3353',
#   'RETURN_STATION_ID': 'ST-262',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '45'},
#  {'BIKE_ID': 'SPB-54933',
#   'RENT_DT': '2024-12-01 01:01:58',
#   'RENT_ID': '01734',
#   'RENT_NM': '쌍문현대1차아파트 108동 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:54',
#   'RTN_ID': '01709',
#   'RTN_NM': '쌍문역4번출구 주변',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1370.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1999',
#   'RENT_STATION_ID': 'ST-1466',
#   'RETURN_STATION_ID': 'ST-616',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '46'},
#  {'BIKE_ID': 'SPB-68664',
#   'RENT_DT': '2024-12-01 01:09:48',
#   'RENT_ID': '02102',
#   'RENT_NM': '봉림교 교통섬',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:56',
#   'RTN_ID': '02102',
#   'RTN_NM': '봉림교 교통섬',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1998',
#   'RENT_STATION_ID': 'ST-702',
#   'RETURN_STATION_ID': 'ST-702',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '47'},
#  {'BIKE_ID': 'SPB-71567',
#   'RENT_DT': '2024-12-01 01:05:02',
#   'RENT_ID': '00501',
#   'RENT_NM': '광진구의회 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:09:57',
#   'RTN_ID': '00588',
#   'RTN_NM': '뚝섬 유원지역',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '577.85',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1994',
#   'RENT_STATION_ID': 'ST-98',
#   'RETURN_STATION_ID': 'ST-483',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '48'},
#  {'BIKE_ID': 'SPB-30616',
#   'RENT_DT': '2024-12-01 01:03:47',
#   'RENT_ID': '01201',
#   'RENT_NM': '가락시장역 3번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:08',
#   'RTN_ID': '01212',
#   'RTN_NM': '송파역 2번 출구앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '475.63',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1994',
#   'RENT_STATION_ID': 'ST-838',
#   'RETURN_STATION_ID': 'ST-839',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '49'},
#  {'BIKE_ID': 'SPB-63160',
#   'RENT_DT': '2024-12-01 01:03:35',
#   'RENT_ID': '00546',
#   'RENT_NM': '잠실대교북단 교차로',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:09',
#   'RTN_ID': '03569',
#   'RTN_NM': '건대병원후문',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1587.04',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1969',
#   'RENT_STATION_ID': 'ST-257',
#   'RETURN_STATION_ID': 'ST-2308',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '50'},
#  {'BIKE_ID': 'SPB-41756',
#   'RENT_DT': '2024-12-01 01:09:22',
#   'RENT_ID': '00540',
#   'RENT_NM': '군자역 7번출구 베스트샵 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:29',
#   'RTN_ID': '00540',
#   'RTN_NM': '군자역 7번출구 베스트샵 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1986',
#   'RENT_STATION_ID': 'ST-253',
#   'RETURN_STATION_ID': 'ST-253',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '51'},
#  {'BIKE_ID': 'SPB-53839',
#   'RENT_DT': '2024-12-01 01:04:26',
#   'RENT_ID': '00265',
#   'RENT_NM': '영등포유통상가 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:29',
#   'RTN_ID': '03206',
#   'RTN_NM': '문래동 주민센터',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '630.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1971',
#   'RENT_STATION_ID': 'ST-419',
#   'RETURN_STATION_ID': 'ST-1977',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '52'},
#  {'BIKE_ID': 'SPB-63448',
#   'RENT_DT': '2024-12-01 01:07:04',
#   'RENT_ID': '03657',
#   'RENT_NM': '서울천호동우체국',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:30',
#   'RTN_ID': '04952',
#   'RTN_NM': '천호시장 버스정류소 옆',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '400.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1999',
#   'RENT_STATION_ID': 'ST-2732',
#   'RETURN_STATION_ID': 'ST-3209',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '53'},
#  {'BIKE_ID': 'SPB-69532',
#   'RENT_DT': '2024-12-01 01:04:34',
#   'RENT_ID': '03010',
#   'RENT_NM': '홍대입구역 3번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:31',
#   'RTN_ID': '00108',
#   'RTN_NM': '서교동 사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '1048.86',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1997',
#   'RENT_STATION_ID': 'ST-2168',
#   'RETURN_STATION_ID': 'ST-10',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '54'},
#  {'BIKE_ID': 'SPB-64896',
#   'RENT_DT': '2024-12-01 01:00:02',
#   'RENT_ID': '03890',
#   'RENT_NM': '웰츠타워 오피스텔',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:36',
#   'RTN_ID': '00549',
#   'RTN_NM': '아차산역 3번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '1700.79',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1969',
#   'RENT_STATION_ID': 'ST-3188',
#   'RETURN_STATION_ID': 'ST-259',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '55'},
#  {'BIKE_ID': 'SPB-57669',
#   'RENT_DT': '2024-12-01 01:02:18',
#   'RENT_ID': '04765',
#   'RENT_NM': '동대문디자인플라자',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:39',
#   'RTN_ID': '00383',
#   'RTN_NM': '신당역 12번 출구 뒤',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1051.18',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1992',
#   'RENT_STATION_ID': 'ST-2431',
#   'RETURN_STATION_ID': 'ST-198',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '56'},
#  {'BIKE_ID': 'SPB-36911',
#   'RENT_DT': '2024-12-01 01:04:43',
#   'RENT_ID': '01991',
#   'RENT_NM': '오류동역 맞은편',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:39',
#   'RTN_ID': '00760',
#   'RTN_NM': '잣절보도육교 아래',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '1331.39',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1965',
#   'RENT_STATION_ID': 'ST-1526',
#   'RETURN_STATION_ID': 'ST-1501',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '57'},
#  {'BIKE_ID': 'SPB-34666',
#   'RENT_DT': '2024-12-01 01:00:37',
#   'RENT_ID': '01601',
#   'RENT_NM': '석계역 문화광장 내 자전거 보관소',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:39',
#   'RTN_ID': '01610',
#   'RTN_NM': '화랑대역 2번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '1988.86',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2005',
#   'RENT_STATION_ID': 'ST-600',
#   'RETURN_STATION_ID': 'ST-603',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '58'},
#  {'BIKE_ID': 'SPB-44161',
#   'RENT_DT': '2024-12-01 01:05:53',
#   'RENT_ID': '05061',
#   'RENT_NM': '우장산동 가곡어린이공원앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:50',
#   'RTN_ID': '01166',
#   'RTN_NM': '강서구립등빛도서관',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '415.52',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1972',
#   'RENT_STATION_ID': 'ST-2888',
#   'RETURN_STATION_ID': 'ST-1351',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '59'},
#  {'BIKE_ID': 'SPB-68890',
#   'RENT_DT': '2024-12-01 01:07:53',
#   'RENT_ID': '04903',
#   'RENT_NM': '신사스퀘어',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:50',
#   'RTN_ID': '03606',
#   'RTN_NM': '신사동주민센터 옆',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': '',
#   'BIRTH_YEAR': '1968',
#   'RENT_STATION_ID': 'ST-3066',
#   'RETURN_STATION_ID': 'ST-2673',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '60'},
#  {'BIKE_ID': 'SPB-41448',
#   'RENT_DT': '2024-12-01 01:02:23',
#   'RENT_ID': '03985',
#   'RENT_NM': '디폴리스 지식산업센터',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:51',
#   'RTN_ID': '01908',
#   'RTN_NM': '해원리바파크 육교 밑',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1490.73',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1983',
#   'RENT_STATION_ID': 'ST-2964',
#   'RETURN_STATION_ID': 'ST-666',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '61'},
#  {'BIKE_ID': 'SPB-40395',
#   'RENT_DT': '2024-12-01 01:03:45',
#   'RENT_ID': '01554',
#   'RENT_NM': '번동사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:53',
#   'RTN_ID': '01569',
#   'RTN_NM': '수유역2번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '945.64',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '2002',
#   'RENT_STATION_ID': 'ST-2127',
#   'RETURN_STATION_ID': 'ST-2137',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '62'},
#  {'BIKE_ID': 'SPB-45444',
#   'RENT_DT': '2024-12-01 01:07:29',
#   'RENT_ID': '01053',
#   'RENT_NM': '동명근린공원 진입로 (아리수로)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:10:56',
#   'RTN_ID': '01021',
#   'RTN_NM': '강일동 리슈빌 빌딩앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '937.61',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1999',
#   'RENT_STATION_ID': 'ST-1594',
#   'RETURN_STATION_ID': 'ST-504',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '63'},
#  {'BIKE_ID': 'SPB-65279',
#   'RENT_DT': '2024-12-01 01:05:35',
#   'RENT_ID': '04804',
#   'RENT_NM': '동서울농협 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:00',
#   'RTN_ID': '01462',
#   'RTN_NM': '동부시장 북문 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '847.23',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-2630',
#   'RETURN_STATION_ID': 'ST-2283',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '64'},
#  {'BIKE_ID': 'SPB-72979',
#   'RENT_DT': '2024-12-01 01:04:17',
#   'RENT_ID': '01004',
#   'RENT_NM': '삼성광나루아파트 버스정류장',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:01',
#   'RTN_ID': '01032',
#   'RTN_NM': '선사고등학교',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '867.88',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1979',
#   'RENT_STATION_ID': 'ST-488',
#   'RETURN_STATION_ID': 'ST-1049',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '65'},
#  {'BIKE_ID': 'SPB-58267',
#   'RENT_DT': '2024-12-01 01:05:37',
#   'RENT_ID': '00539',
#   'RENT_NM': '군자교교차로',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:04',
#   'RTN_ID': '03517',
#   'RTN_NM': '용마사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '774.20',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1970',
#   'RENT_STATION_ID': 'ST-252',
#   'RETURN_STATION_ID': 'ST-1266',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '66'},
#  {'BIKE_ID': 'SPB-46507',
#   'RENT_DT': '2024-12-01 01:03:06',
#   'RENT_ID': '00113',
#   'RENT_NM': '홍대입구역 2번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:18',
#   'RTN_ID': '03119',
#   'RTN_NM': '연희 브라운스톤 아파트 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1130.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'RENT_STATION_ID': 'ST-18',
#   'RETURN_STATION_ID': 'ST-2204',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '67'},
#  {'BIKE_ID': 'SPB-64837',
#   'RENT_DT': '2024-12-01 01:07:45',
#   'RENT_ID': '00725',
#   'RENT_NM': '양강중학교앞 교차로',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:24',
#   'RTN_ID': '01145',
#   'RTN_NM': '곰달래 문화복지센터 B',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '760.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1965',
#   'RENT_STATION_ID': 'ST-996',
#   'RETURN_STATION_ID': 'ST-536',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '68'},
#  {'BIKE_ID': 'SPB-72827',
#   'RENT_DT': '2024-12-01 01:02:55',
#   'RENT_ID': '04868',
#   'RENT_NM': '석촌호수 서호 남단',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:28',
#   'RTN_ID': '05768',
#   'RTN_NM': '방이삼거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '908.05',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1963',
#   'RENT_STATION_ID': 'ST-2833',
#   'RETURN_STATION_ID': 'ST-3214',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '69'},
#  {'BIKE_ID': 'SPB-56891',
#   'RENT_DT': '2024-12-01 01:05:25',
#   'RENT_ID': '04080',
#   'RENT_NM': '창동주공19단지앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:35',
#   'RTN_ID': '04090',
#   'RTN_NM': '녹천교 앞 사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '830.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1991',
#   'RENT_STATION_ID': 'ST-2967',
#   'RETURN_STATION_ID': 'ST-3175',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '70'},
#  {'BIKE_ID': 'SPB-70596',
#   'RENT_DT': '2024-12-01 01:06:29',
#   'RENT_ID': '00374',
#   'RENT_NM': '청구역 2번출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:42',
#   'RTN_ID': '00480',
#   'RTN_NM': '약수역 6번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '796.13',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1959',
#   'RENT_STATION_ID': 'ST-189',
#   'RETURN_STATION_ID': 'ST-1786',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '71'},
#  {'BIKE_ID': 'SPB-52030',
#   'RENT_DT': '2024-12-01 01:02:37',
#   'RENT_ID': '01637',
#   'RENT_NM': 'KT 전화국 버스정류장 옆',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:44',
#   'RTN_ID': '04037',
#   'RTN_NM': '물넘이교',
#   'RTN_HOLD': '0',
#   'USE_MIN': '9',
#   'USE_DST': '1060.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2007',
#   'RENT_STATION_ID': 'ST-611',
#   'RETURN_STATION_ID': 'ST-2835',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '72'},
#  {'BIKE_ID': 'SPB-72441',
#   'RENT_DT': '2024-12-01 01:08:06',
#   'RENT_ID': '03002',
#   'RENT_NM': '벽산상암스마트큐브',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:46',
#   'RTN_ID': '00427',
#   'RTN_NM': '성산시영아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '492.30',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '1973',
#   'RENT_STATION_ID': 'ST-2160',
#   'RETURN_STATION_ID': 'ST-1397',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '73'},
#  {'BIKE_ID': 'SPB-62600',
#   'RENT_DT': '2024-12-01 01:07:39',
#   'RENT_ID': '01986',
#   'RENT_NM': '태평양물산',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:53',
#   'RTN_ID': '01962',
#   'RTN_NM': '가리봉동주민센터',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '380.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1962',
#   'RENT_STATION_ID': 'ST-1521',
#   'RETURN_STATION_ID': 'ST-1224',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '74'},
#  {'BIKE_ID': 'SPB-64242',
#   'RENT_DT': '2024-12-01 01:00:43',
#   'RENT_ID': '05315',
#   'RENT_NM': '당고개역 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:55',
#   'RTN_ID': '01683',
#   'RTN_NM': '노원문화예술회관',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '2681.25',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-3134',
#   'RETURN_STATION_ID': 'ST-1473',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '75'},
#  {'BIKE_ID': 'SPB-67539',
#   'RENT_DT': '2024-12-01 01:06:12',
#   'RENT_ID': '01008',
#   'RENT_NM': '암사역 3번출구(국민은행앞)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:11:59',
#   'RTN_ID': '01060',
#   'RTN_NM': '천일초교 사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '860.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1963',
#   'RENT_STATION_ID': 'ST-492',
#   'RETURN_STATION_ID': 'ST-1620',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '76'},
#  {'BIKE_ID': 'SPB-41979',
#   'RENT_DT': '2024-12-01 01:08:40',
#   'RENT_ID': '04036',
#   'RENT_NM': '하계역 6번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:00',
#   'RTN_ID': '01650',
#   'RTN_NM': '중계근린공원내',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '317.94',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1971',
#   'RENT_STATION_ID': 'ST-2792',
#   'RETURN_STATION_ID': 'ST-1118',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '77'},
#  {'BIKE_ID': 'SPB-72574',
#   'RENT_DT': '2024-12-01 01:03:21',
#   'RENT_ID': '04277',
#   'RENT_NM': '서대문우체국 정류소 옆',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:01',
#   'RTN_ID': '00114',
#   'RTN_NM': '홍대입구역 8번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '364.28',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'RENT_STATION_ID': 'ST-3347',
#   'RETURN_STATION_ID': 'ST-20',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '78'},
#  {'BIKE_ID': 'SPB-48476',
#   'RENT_DT': '2024-12-01 01:09:53',
#   'RENT_ID': '00275',
#   'RENT_NM': '신동아아파트',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:06',
#   'RTN_ID': '04571',
#   'RTN_NM': '문래동롯데캐슬아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '500.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1985',
#   'RENT_STATION_ID': 'ST-1320',
#   'RETURN_STATION_ID': 'ST-2820',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '79'},
#  {'BIKE_ID': 'SPB-65269',
#   'RENT_DT': '2024-12-01 01:04:23',
#   'RENT_ID': '01565',
#   'RENT_NM': '수유사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:15',
#   'RTN_ID': '01742',
#   'RTN_NM': '북한산 코오롱 하늘채',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1620.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2003',
#   'RENT_STATION_ID': 'ST-2134',
#   'RETURN_STATION_ID': 'ST-1726',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '80'},
#  {'BIKE_ID': 'SPB-62963',
#   'RENT_DT': '2024-12-01 01:04:32',
#   'RENT_ID': '01308',
#   'RENT_NM': '안암로터리 버스정류장 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:20',
#   'RTN_ID': '00362',
#   'RTN_NM': '청계8가사거리 A',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1357.24',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-827',
#   'RETURN_STATION_ID': 'ST-176',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '81'},
#  {'BIKE_ID': 'SPB-61531',
#   'RENT_DT': '2024-12-01 01:05:20',
#   'RENT_ID': '01011',
#   'RENT_NM': 'LIGA 아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:24',
#   'RTN_ID': '01020',
#   'RTN_NM': '강동경찰서',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1310.00',
#   'USR_CLS_CD': 'USR_001',
#   'RENT_STATION_ID': 'ST-495',
#   'RETURN_STATION_ID': 'ST-503',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '82'},
#  {'BIKE_ID': 'SPB-46846',
#   'RENT_DT': '2024-12-01 01:00:40',
#   'RENT_ID': '00731',
#   'RENT_NM': '서울시 도로환경관리센터',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:39',
#   'RTN_ID': '00754',
#   'RTN_NM': '목동1단지아파트 118동 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '1414.82',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1976',
#   'RENT_STATION_ID': 'ST-1002',
#   'RETURN_STATION_ID': 'ST-1495',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '83'},
#  {'BIKE_ID': 'SPB-63829',
#   'RENT_DT': '2024-12-01 01:02:59',
#   'RENT_ID': '00280',
#   'RENT_NM': '양평동6차현대아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:43',
#   'RTN_ID': '04561',
#   'RTN_NM': '양평역 1번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '9',
#   'USE_DST': '1188.04',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-1539',
#   'RETURN_STATION_ID': 'ST-2812',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '84'},
#  {'BIKE_ID': 'SPB-40461',
#   'RENT_DT': '2024-12-01 01:05:49',
#   'RENT_ID': '01960',
#   'RENT_NM': '구로거리공원 동측(신도림역 방면)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:12:55',
#   'RTN_ID': '04566',
#   'RTN_NM': '대림성원상떼빌아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '599.46',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1981',
#   'RENT_STATION_ID': 'ST-1222',
#   'RETURN_STATION_ID': 'ST-2816',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '85'},
#  {'BIKE_ID': 'SPB-43512',
#   'RENT_DT': '2024-12-01 01:02:00',
#   'RENT_ID': '01991',
#   'RENT_NM': '오류동역 맞은편',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:01',
#   'RTN_ID': '01952',
#   'RTN_NM': '천왕연지타운2단지 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '2106.05',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2008',
#   'RENT_STATION_ID': 'ST-1526',
#   'RETURN_STATION_ID': 'ST-875',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '86'},
#  {'BIKE_ID': 'SPB-50866',
#   'RENT_DT': '2024-12-01 01:11:22',
#   'RENT_ID': '02641',
#   'RENT_NM': '송파역 4번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:01',
#   'RTN_ID': '04864',
#   'RTN_NM': '송파사거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1990',
#   'RENT_STATION_ID': 'ST-1793',
#   'RETURN_STATION_ID': 'ST-2796',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '87'},
#  {'BIKE_ID': 'SPB-66878',
#   'RENT_DT': '2024-12-01 01:02:38',
#   'RENT_ID': '00781',
#   'RENT_NM': '신정보도육교 아래',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:05',
#   'RTN_ID': '04541',
#   'RTN_NM': '갈산문화예술센터',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '1280.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2007',
#   'RENT_STATION_ID': 'ST-2007',
#   'RETURN_STATION_ID': 'ST-3089',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '88'},
#  {'BIKE_ID': 'SPB-47634',
#   'RENT_DT': '2024-12-01 01:07:05',
#   'RENT_ID': '00648',
#   'RENT_NM': '장안동위더스빌옆',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:16',
#   'RTN_ID': '04137',
#   'RTN_NM': '답십리역 4번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '877.76',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1974',
#   'RENT_STATION_ID': 'ST-1300',
#   'RETURN_STATION_ID': 'ST-3316',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '89'},
#  {'BIKE_ID': 'SPB-44500',
#   'RENT_DT': '2024-12-01 01:02:26',
#   'RENT_ID': '00719',
#   'RENT_NM': '홍익병원앞 교차로',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:19',
#   'RTN_ID': '00796',
#   'RTN_NM': '목동아파트 14단지 B상가 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '1956.62',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1990',
#   'RENT_STATION_ID': 'ST-431',
#   'RETURN_STATION_ID': 'ST-2397',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '90'},
#  {'BIKE_ID': 'SPB-33700',
#   'RENT_DT': '2024-12-01 01:08:31',
#   'RENT_ID': '01605',
#   'RENT_NM': '헬스케어',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:19',
#   'RTN_ID': '01641',
#   'RTN_NM': '한내근린공원 남측',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '1317.33',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '1973',
#   'RENT_STATION_ID': 'ST-866',
#   'RETURN_STATION_ID': 'ST-970',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '91'},
#  {'BIKE_ID': 'SPB-82123',
#   'RENT_DT': '2024-12-01 01:03:20',
#   'RENT_ID': '04340',
#   'RENT_NM': '방배래미안아트힐아파트 앞',
#   'RENT_HOLD': '99',
#   'RTN_DT': '2024-12-01 01:13:23',
#   'RTN_ID': '02510',
#   'RTN_NM': 'JW타워',
#   'RTN_HOLD': '99',
#   'USE_MIN': '10',
#   'USE_DST': '1720.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1967',
#   'RENT_STATION_ID': 'ST-3220',
#   'RETURN_STATION_ID': 'ST-1735',
#   'BIKE_SE_CD': '새싹자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '92'},
#  {'BIKE_ID': 'SPB-61292',
#   'RENT_DT': '2024-12-01 01:09:35',
#   'RENT_ID': '03534',
#   'RENT_NM': '건대입구역 5번출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:24',
#   'RTN_ID': '00588',
#   'RTN_NM': '뚝섬 유원지역',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '898.32',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1995',
#   'RENT_STATION_ID': 'ST-1661',
#   'RETURN_STATION_ID': 'ST-483',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '93'},
#  {'BIKE_ID': 'SPB-40110',
#   'RENT_DT': '2024-12-01 01:00:10',
#   'RENT_ID': '03894',
#   'RENT_NM': '노룬산시장 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:27',
#   'RTN_ID': '03575',
#   'RTN_NM': '자양사거리(서원빌딩)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '13',
#   'USE_DST': '2056.29',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1985',
#   'RENT_STATION_ID': 'ST-3309',
#   'RETURN_STATION_ID': 'ST-2314',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '94'},
#  {'BIKE_ID': 'SPB-53341',
#   'RENT_DT': '2024-12-01 01:07:23',
#   'RENT_ID': '02429',
#   'RENT_NM': '압구정로데오역 6번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:28',
#   'RTN_ID': '02306',
#   'RTN_NM': '압구정역 2번 출구 옆',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1100.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1988',
#   'RENT_STATION_ID': 'ST-1895',
#   'RETURN_STATION_ID': 'ST-791',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '95'},
#  {'BIKE_ID': 'SPB-43491',
#   'RENT_DT': '2024-12-01 01:05:42',
#   'RENT_ID': '00483',
#   'RENT_NM': '남산타운아파트 버스정류장',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:30',
#   'RTN_ID': '06054',
#   'RTN_NM': '청구e편한세상아파트 113동 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1574.21',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2006',
#   'RENT_STATION_ID': 'ST-1789',
#   'RETURN_STATION_ID': 'ST-3210',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '96'},
#  {'BIKE_ID': 'SPB-51999',
#   'RENT_DT': '2024-12-01 01:10:42',
#   'RENT_ID': '03882',
#   'RENT_NM': '자양2동 주민센터',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:31',
#   'RTN_ID': '03536',
#   'RTN_NM': '중앙농협(자양동)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '2',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1991',
#   'RENT_STATION_ID': 'ST-2891',
#   'RETURN_STATION_ID': 'ST-1663',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '97'},
#  {'BIKE_ID': 'SPB-60025',
#   'RENT_DT': '2024-12-01 01:02:15',
#   'RENT_ID': '00280',
#   'RENT_NM': '양평동6차현대아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:34',
#   'RTN_ID': '04561',
#   'RTN_NM': '양평역 1번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '1144.58',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1998',
#   'RENT_STATION_ID': 'ST-1539',
#   'RETURN_STATION_ID': 'ST-2812',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '98'},
#  {'BIKE_ID': 'SPB-61221',
#   'RENT_DT': '2024-12-01 01:04:43',
#   'RENT_ID': '01911',
#   'RENT_NM': '구로디지털단지역 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:34',
#   'RTN_ID': '02176',
#   'RTN_NM': '보라매공원 보도육교',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1522.62',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-668',
#   'RETURN_STATION_ID': 'ST-1357',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '99'},
#  {'BIKE_ID': 'SPB-71131',
#   'RENT_DT': '2024-12-01 01:02:59',
#   'RENT_ID': '04543',
#   'RENT_NM': '오목교역 6번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:13:35',
#   'RTN_ID': '00729',
#   'RTN_NM': '서부식자재마트 건너편',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '2220.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1995',
#   'RENT_STATION_ID': 'ST-3163',
#   'RETURN_STATION_ID': 'ST-1000',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '100'},
#  {'BIKE_ID': 'SPB-45193',
#   'RENT_DT': '2024-12-01 01:07:25',
#   'RENT_ID': '00383',
# ...
#  {'BIKE_ID': 'SPB-64583',
#   'RENT_DT': '2024-12-01 01:45:35',
#   'RENT_ID': '04620',
#   'RENT_NM': '삼각지역 14번 출구 앞(교통섬)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:53:53',
#   'RTN_ID': '04633',
#   'RTN_NM': '센트럴파크타워 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1130.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1971',
#   'RENT_STATION_ID': 'ST-2451',
#   'RETURN_STATION_ID': 'ST-2924',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '968'},
#  {'BIKE_ID': 'SPB-48718',
#   'RENT_DT': '2024-12-01 01:16:57',
#   'RENT_ID': '00361',
#   'RENT_NM': '동묘앞역 1번출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:53:53',
#   'RTN_ID': '01321',
#   'RTN_NM': '국민은행 종암동지점 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '36',
#   'USE_DST': '4640.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1999',
#   'RENT_STATION_ID': 'ST-175',
#   'RETURN_STATION_ID': 'ST-655',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '969'},
#  {'BIKE_ID': 'SPB-63551',
#   'RENT_DT': '2024-12-01 01:45:08',
#   'RENT_ID': '02818',
#   'RENT_NM': '천왕이펜하우스3단지 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:53:55',
#   'RTN_ID': '03908',
#   'RTN_NM': '오류동 다숲오피스텔 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '8',
#   'USE_DST': '1236.59',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '1961',
#   'RENT_STATION_ID': 'ST-1958',
#   'RETURN_STATION_ID': 'ST-2753',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '970'},
#  {'BIKE_ID': 'SPB-45112',
#   'RENT_DT': '2024-12-01 01:53:31',
#   'RENT_ID': '00259',
#   'RENT_NM': '대방역6번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:02',
#   'RTN_ID': '00259',
#   'RTN_NM': '대방역6번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '0',
#   'USE_DST': '0.00',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1995',
#   'RENT_STATION_ID': 'ST-307',
#   'RETURN_STATION_ID': 'ST-307',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '971'},
#  {'BIKE_ID': 'SPB-33334',
#   'RENT_DT': '2024-12-01 01:47:12',
#   'RENT_ID': '03657',
#   'RENT_NM': '서울천호동우체국',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:02',
#   'RTN_ID': '01061',
#   'RTN_NM': '천호초교 입구 사거리(일주빌딩)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1081.88',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1961',
#   'RENT_STATION_ID': 'ST-2732',
#   'RETURN_STATION_ID': 'ST-1621',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '972'},
#  {'BIKE_ID': 'SPB-35003',
#   'RENT_DT': '2024-12-01 01:50:30',
#   'RENT_ID': '00950',
#   'RENT_NM': '구산역 2번 출구 예일여고 버스정류장',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:05',
#   'RTN_ID': '00906',
#   'RTN_NM': '연신내역 5번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '3',
#   'USE_DST': '812.25',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1969',
#   'RENT_STATION_ID': 'ST-1036',
#   'RETURN_STATION_ID': 'ST-454',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '973'},
#  {'BIKE_ID': 'SPB-37922',
#   'RENT_DT': '2024-12-01 01:43:40',
#   'RENT_ID': '00612',
#   'RENT_NM': '시립동부병원 앞 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:06',
#   'RTN_ID': '00631',
#   'RTN_NM': '답십리역 1번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '10',
#   'USE_DST': '1903.73',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1996',
#   'RENT_STATION_ID': 'ST-271',
#   'RETURN_STATION_ID': 'ST-398',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '974'},
#  {'BIKE_ID': 'SPB-67900',
#   'RENT_DT': '2024-12-01 01:34:26',
#   'RENT_ID': '05333',
#   'RENT_NM': '노원역9번-10번 출구 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:20',
#   'RTN_ID': '04065',
#   'RTN_NM': '창동역 1번출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '19',
#   'USE_DST': '2200.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1981',
#   'RENT_STATION_ID': 'ST-3288',
#   'RETURN_STATION_ID': 'ST-2726',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '975'},
#  {'BIKE_ID': 'SPB-55059',
#   'RENT_DT': '2024-12-01 01:46:30',
#   'RENT_ID': '03936',
#   'RENT_NM': '힐스테이트 신도림역',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:24',
#   'RTN_ID': '00236',
#   'RTN_NM': '문래동자이아파트 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '1431.58',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1963',
#   'RENT_STATION_ID': 'ST-3303',
#   'RETURN_STATION_ID': 'ST-285',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '976'},
#  {'BIKE_ID': 'SPB-60936',
#   'RENT_DT': '2024-12-01 01:34:40',
#   'RENT_ID': '01193',
#   'RENT_NM': '마곡센트럴타워 1차',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:29',
#   'RTN_ID': '02711',
#   'RTN_NM': '가로공원공영주차장 1번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '19',
#   'USE_DST': '2855.66',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '2001',
#   'RENT_STATION_ID': 'ST-1688',
#   'RETURN_STATION_ID': 'ST-2027',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '977'},
#  {'BIKE_ID': 'SPB-68355',
#   'RENT_DT': '2024-12-01 01:39:12',
#   'RENT_ID': '03963',
#   'RENT_NM': '에이스 하드웨어(시흥대로 396) 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:35',
#   'RTN_ID': '01914',
#   'RTN_NM': '대림역4번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '15',
#   'USE_DST': '3360.57',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1972',
#   'RENT_STATION_ID': 'ST-2641',
#   'RETURN_STATION_ID': 'ST-918',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '978'},
#  {'BIKE_ID': 'SPB-48364',
#   'RENT_DT': '2024-12-01 01:53:27',
#   'RENT_ID': '02637',
#   'RENT_NM': '아시아지하보도 14번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:39',
#   'RTN_ID': '02637',
#   'RTN_NM': '아시아지하보도 14번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '1',
#   'USE_DST': '20.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2000',
#   'RENT_STATION_ID': 'ST-1864',
#   'RETURN_STATION_ID': 'ST-1864',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '979'},
#  {'BIKE_ID': 'SPB-37751',
#   'RENT_DT': '2024-12-01 01:50:40',
#   'RENT_ID': '00660',
#   'RENT_NM': '동의보감타워',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:46',
#   'RTN_ID': '00676',
#   'RTN_NM': 'FITI시험연구원 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '310.51',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1999',
#   'RENT_STATION_ID': 'ST-1632',
#   'RETURN_STATION_ID': 'ST-2276',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '980'},
#  {'BIKE_ID': 'SPB-64301',
#   'RENT_DT': '2024-12-01 01:49:38',
#   'RENT_ID': '00962',
#   'RENT_NM': '은평뉴타운 힐데스하임',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:48',
#   'RTN_ID': '00959',
#   'RTN_NM': '구파발10단지 인근',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '687.52',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1997',
#   'RENT_STATION_ID': 'ST-1483',
#   'RETURN_STATION_ID': 'ST-1480',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '981'},
#  {'BIKE_ID': 'SPB-37942',
#   'RENT_DT': '2024-12-01 01:48:06',
#   'RENT_ID': '02012',
#   'RENT_NM': '대림사거리(동작상떼빌아파트)',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:51',
#   'RTN_ID': '02110',
#   'RTN_NM': '조원동 미성아파트',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '611.65',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1989',
#   'RENT_STATION_ID': 'ST-727',
#   'RETURN_STATION_ID': 'ST-950',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '982'},
#  {'BIKE_ID': 'SPB-59684',
#   'RENT_DT': '2024-12-01 01:42:59',
#   'RENT_ID': '02619',
#   'RENT_NM': '석촌고분역 4번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:54',
#   'RTN_ID': '04497',
#   'RTN_NM': '아시아선수촌아파트 교차로',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '1647.17',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '1998',
#   'RENT_STATION_ID': 'ST-1729',
#   'RETURN_STATION_ID': 'ST-2602',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '983'},
#  {'BIKE_ID': 'SPB-63739',
#   'RENT_DT': '2024-12-01 01:17:10',
#   'RENT_ID': '01222',
#   'RENT_NM': '잠실새내역 5번 출구 뒤',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:55',
#   'RTN_ID': '00514',
#   'RTN_NM': '성수사거리 버스정류장 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '37',
#   'USE_DST': '7006.75',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1998',
#   'RENT_STATION_ID': 'ST-547',
#   'RETURN_STATION_ID': 'ST-112',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '984'},
#  {'BIKE_ID': 'SPB-43382',
#   'RENT_DT': '2024-12-01 01:50:16',
#   'RENT_ID': '01199',
#   'RENT_NM': '우장산역 3번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:55',
#   'RTN_ID': '02739',
#   'RTN_NM': '수명산파크1단지교차로',
#   'RTN_HOLD': '0',
#   'USE_MIN': '4',
#   'USE_DST': '925.67',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'F',
#   'BIRTH_YEAR': '1977',
#   'RENT_STATION_ID': 'ST-1694',
#   'RETURN_STATION_ID': 'ST-2056',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '985'},
#  {'BIKE_ID': 'SPB-41901',
#   'RENT_DT': '2024-12-01 01:49:51',
#   'RENT_ID': '01169',
#   'RENT_NM': '염창역 1번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:54:57',
#   'RTN_ID': '00744',
#   'RTN_NM': '신목동역 2번 출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '802.83',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1991',
#   'RENT_STATION_ID': 'ST-1506',
#   'RETURN_STATION_ID': 'ST-1015',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '986'},
#  {'BIKE_ID': 'SPB-58252',
#   'RENT_DT': '2024-12-01 01:47:14',
#   'RENT_ID': '05339',
#   'RENT_NM': '은빛1단지 아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:02',
#   'RTN_ID': '01628',
#   'RTN_NM': '노일초등학교 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '7',
#   'USE_DST': '830.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1962',
#   'RENT_STATION_ID': 'ST-3299',
#   'RETURN_STATION_ID': 'ST-868',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '987'},
#  {'BIKE_ID': 'SPB-71969',
#   'RENT_DT': '2024-12-01 01:39:28',
#   'RENT_ID': '02385',
#   'RENT_NM': '학동역',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:07',
#   'RTN_ID': '02365',
#   'RTN_NM': 'K+ 타워 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '15',
#   'USE_DST': '1855.38',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1960',
#   'RENT_STATION_ID': 'ST-1365',
#   'RETURN_STATION_ID': 'ST-1174',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '988'},
#  {'BIKE_ID': 'SPB-36399',
#   'RENT_DT': '2024-12-01 01:27:33',
#   'RENT_ID': '04370',
#   'RENT_NM': '성동교 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:11',
#   'RTN_ID': '00535',
#   'RTN_NM': '응봉삼거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '27',
#   'USE_DST': '2142.58',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '1994',
#   'RENT_STATION_ID': 'ST-2834',
#   'RETURN_STATION_ID': 'ST-247',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '989'},
#  {'BIKE_ID': 'SPB-59415',
#   'RENT_DT': '2024-12-01 01:43:52',
#   'RENT_ID': '01431',
#   'RENT_NM': '중랑구청 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:21',
#   'RTN_ID': '01474',
#   'RTN_NM': '서울중랑우체국',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '1899.18',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1963',
#   'RENT_STATION_ID': 'ST-856',
#   'RETURN_STATION_ID': 'ST-2295',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '990'},
#  {'BIKE_ID': 'SPB-63136',
#   'RENT_DT': '2024-12-01 01:48:33',
#   'RENT_ID': '04532',
#   'RENT_NM': '목동현대아파트 후문 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:21',
#   'RTN_ID': '05885',
#   'RTN_NM': '신정교하부(도림천역 방면)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1030.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2002',
#   'RENT_STATION_ID': 'ST-2879',
#   'RETURN_STATION_ID': 'ST-3341',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '991'},
#  {'BIKE_ID': 'SPB-43822',
#   'RENT_DT': '2024-12-01 01:28:08',
#   'RENT_ID': '04370',
#   'RENT_NM': '성동교 사거리',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:21',
#   'RTN_ID': '00535',
#   'RTN_NM': '응봉삼거리',
#   'RTN_HOLD': '0',
#   'USE_MIN': '27',
#   'USE_DST': '2182.98',
#   'USR_CLS_CD': 'USR_003',
#   'RENT_STATION_ID': 'ST-2834',
#   'RETURN_STATION_ID': 'ST-247',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '992'},
#  {'BIKE_ID': 'SPB-67768',
#   'RENT_DT': '2024-12-01 01:43:31',
#   'RENT_ID': '01531',
#   'RENT_NM': '미아사거리 1번 출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:26',
#   'RTN_ID': '01327',
#   'RTN_NM': '상월곡역 3번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '11',
#   'USE_DST': '2500.00',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1997',
#   'RENT_STATION_ID': 'ST-1105',
#   'RETURN_STATION_ID': 'ST-574',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '993'},
#  {'BIKE_ID': 'SPB-64132',
#   'RENT_DT': '2024-12-01 01:30:22',
#   'RENT_ID': '02658',
#   'RENT_NM': '가락몰 업무동',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:26',
#   'RTN_ID': '01084',
#   'RTN_NM': '윤선생빌딩(JYP사옥)',
#   'RTN_HOLD': '0',
#   'USE_MIN': '25',
#   'USE_DST': '4265.64',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '2001',
#   'RENT_STATION_ID': 'ST-2409',
#   'RETURN_STATION_ID': 'ST-1687',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '994'},
#  {'BIKE_ID': 'SPB-37240',
#   'RENT_DT': '2024-12-01 01:42:20',
#   'RENT_ID': '02713',
#   'RENT_NM': '우장초등학교 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:27',
#   'RTN_ID': '00741',
#   'RTN_NM': '화곡로 입구 교차로',
#   'RTN_HOLD': '0',
#   'USE_MIN': '13',
#   'USE_DST': '2482.30',
#   'USR_CLS_CD': 'USR_001',
#   'BIRTH_YEAR': '2002',
#   'RENT_STATION_ID': 'ST-2029',
#   'RETURN_STATION_ID': 'ST-1012',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '995'},
#  {'BIKE_ID': 'SPB-57724',
#   'RENT_DT': '2024-12-01 01:35:07',
#   'RENT_ID': '01639',
#   'RENT_NM': '희성오피앙',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:28',
#   'RTN_ID': '05333',
#   'RTN_NM': '노원역9번-10번 출구 앞',
#   'RTN_HOLD': '0',
#   'USE_MIN': '20',
#   'USE_DST': '3013.84',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1970',
#   'RENT_STATION_ID': 'ST-612',
#   'RETURN_STATION_ID': 'ST-3288',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '996'},
#  {'BIKE_ID': 'SPB-72651',
#   'RENT_DT': '2024-12-01 01:49:01',
#   'RENT_ID': '00617',
#   'RENT_NM': '청솔우성아파트 앞',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:35',
#   'RTN_ID': '04137',
#   'RTN_NM': '답십리역 4번출구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '6',
#   'USE_DST': '1072.73',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1970',
#   'RENT_STATION_ID': 'ST-276',
#   'RETURN_STATION_ID': 'ST-3316',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '997'},
#  {'BIKE_ID': 'SPB-31160',
#   'RENT_DT': '2024-12-01 01:28:54',
#   'RENT_ID': '04852',
#   'RENT_NM': '서울복합물류 게이트 1',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:37',
#   'RTN_ID': '04891',
#   'RTN_NM': '위례포레나송파',
#   'RTN_HOLD': '0',
#   'USE_MIN': '26',
#   'USE_DST': '2935.54',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1972',
#   'RENT_STATION_ID': 'ST-2605',
#   'RETURN_STATION_ID': 'ST-3004',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '998'},
#  {'BIKE_ID': 'SPB-58772',
#   'RENT_DT': '2024-12-01 01:39:30',
#   'RENT_ID': '00670',
#   'RENT_NM': '삼육서울병원 버스정류장',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:38',
#   'RTN_ID': '00670',
#   'RTN_NM': '삼육서울병원 버스정류장',
#   'RTN_HOLD': '0',
#   'USE_MIN': '16',
#   'USE_DST': '1103.70',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1969',
#   'RENT_STATION_ID': 'ST-2270',
#   'RETURN_STATION_ID': 'ST-2270',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '999'},
#  {'BIKE_ID': 'SPB-44088',
#   'RENT_DT': '2024-12-01 01:49:53',
#   'RENT_ID': '03219',
#   'RENT_NM': '영등포역 1번출구',
#   'RENT_HOLD': '0',
#   'RTN_DT': '2024-12-01 01:55:39',
#   'RTN_ID': '00256',
#   'RTN_NM': '동아에코빌입구',
#   'RTN_HOLD': '0',
#   'USE_MIN': '5',
#   'USE_DST': '1199.90',
#   'USR_CLS_CD': 'USR_001',
#   'SEX_CD': 'M',
#   'BIRTH_YEAR': '1984',
#   'RENT_STATION_ID': 'ST-1990',
#   'RETURN_STATION_ID': 'ST-304',
#   'BIKE_SE_CD': '일반자전거',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1000'}]

# %%
import os
import requests
import pandas as pd

class SeoulBikeHotPlaces:
    def __init__(self, api_key=None):
        """
        Google Places API 키를 초기화합니다.
        :param api_key: Google Places API 키 (환경 변수 또는 직접 입력)
        """
        self.api_key = api_key or os.getenv('gmaps_api_key')
        if not self.api_key:
            raise ValueError("Google Places API Key가 필요합니다. 환경 변수로 설정하거나 직접 전달하세요.")
    
    def get_hot_places(self, latitude, longitude, radius=500, place_type="tourist_attraction"):
        """
        특정 위치 주변의 핫플레이스를 검색합니다.
        :param latitude: 검색 중심점의 위도
        :param longitude: 검색 중심점의 경도
        :param radius: 검색 반경 (미터 단위, 기본값: 500m)
        :param place_type: 검색할 장소 유형 (예: restaurant, cafe, park 등)
        :return: 핫플레이스 정보 리스트
        """
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        params = {
            "location": f"{latitude},{longitude}",
            "radius": radius,
            "type": place_type,
            "key": self.api_key
        }
        
        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
            data = response.json()
            
            # 결과에서 필요한 정보 추출
            places = []
            for result in data.get("results", []):
                places.append({
                    "name": result.get("name"),
                    "latitude": result["geometry"]["location"]["lat"],
                    "longitude": result["geometry"]["location"]["lng"],
                    "rating": result.get("rating"),
                    "user_ratings_total": result.get("user_ratings_total"),
                    "address": result.get("vicinity")
                })
            
            return places
        
        except requests.exceptions.RequestException as e:
            print(f"데이터를 가져오는 중 오류가 발생했습니다: {e}")
            return []
    
    def get_places_for_stations(self, bike_stations_df, radius=500, place_type="tourist_attraction"):
        """
        자전거 대여소 데이터프레임을 기반으로 각 대여소 주변 핫플레이스를 검색합니다.
        :param bike_stations_df: 자전거 대여소 정보가 포함된 DataFrame (latitude와 longitude 열 포함)
        :param radius: 검색 반경 (미터 단위, 기본값: 500m)
        :param place_type: 검색할 장소 유형 (예: restaurant, cafe, park 등)
        :return: 대여소별 핫플레이스 정보를 포함한 DataFrame
        """
        all_places = []
        
        for _, row in bike_stations_df.iterrows():
            station_id = row["stationId"]
            station_name = row["stationName"]
            latitude = row["stationLatitude"]
            longitude = row["stationLongitude"]
            
            print(f"대여소 '{station_name}' 주변 핫플레이스 검색 중...")
            
            # 특정 대여소 주변 핫플레이스 검색
            places = self.get_hot_places(latitude, longitude, radius=radius, place_type=place_type)
            
            # 각 장소에 대여소 ID와 이름 추가
            for place in places:
                place["stationId"] = station_id
                place["stationName"] = station_name
            
            all_places.extend(places)
        
        # 결과를 DataFrame으로 변환
        return pd.DataFrame(all_places)
